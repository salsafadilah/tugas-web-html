# %% [markdown]
# <a href="https://colab.research.google.com/github/salsafadilah/tugas-web-html/blob/main/ILOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'nama':['salsa','safira','carlita'],
    'usia':[23,24,25],
    'kota':['bogor','depok','jakarta']
}
df = pd.DataFrame(data)

# %%
df.iloc[0]
# Out:
# nama    salsa
# usia       23
# kota    bogor
# Name: 0, dtype: object

# %%
df.iloc[0:2, 1]
# Out:
# 0    23
# 1    24
# Name: usia, dtype: int64

# %%
df.iloc[0:4, 2]
# Out:
# 0      bogor
# 1      depok
# 2    jakarta
# Name: kota, dtype: object

# %%
df.iloc[0:3, 0:2]
# Out:
#       nama  usia
# 0    salsa    23
# 1   safira    24
# 2  carlita    25

# %%
df.iloc[ ,0:3]
# Out:
#   File "/tmp/ipykernel_27426/2675299841.py", line 1
#     df.iloc[ ,0:3]
#              ^
# SyntaxError: invalid syntax

# %%
x = dataset.iloc[:,1:3],values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27426/3033289328.py in <cell line: 0>()
# ----> 1 x = dataset.iloc[:,1:3],values
#
# NameError: name 'dataset' is not defined
